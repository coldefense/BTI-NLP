# %%
import csv
import json

# %%
import pandas as pd
annotations_data = pd.read_csv("lrb_annotations.csv")
annotations_data
# Out:
#                                                  text  \
# 0   The best characterized ligands for the AhR inc...
# 1    The IGFBPs bind IGF-I and IGF-II in the circu...
# 2   Schutz et al. found a 4-12-fold and 100-fold i...
# 3   For CB1 we also modeled the whole N-terminal p...
# 4   build a structural model of the NPY-Y5 R compl...
# ..                                                ...
# 95  The second transgene, CreERT2 (brown), encodes...
# 96  an envelope protein of herpes simplex virus, f...
# 97  The IgE tail region binds to another class of ...
# 98  A monoclonal antibody called trastuzumab (trad...
# 99  the lymphocytes stop rolling, and they crawl o...
#
#                                   sourcedb            sourceid
# 0                                   PubMed            31337850
# 1                                   PubMed            33962049
# 2                                   PubMed            37240408
# 3                                   PubMed            32326322
# 4                                   PubMed            34822209
# ..                                     ...                 ...
# 95  Molecular Biology of the Cell Textbook  ISBN 9780393884861
# 96  Molecular Biology of the Cell Textbook  ISBN 9780393884862
# 97  Molecular Biology of the Cell Textbook  ISBN 9780393884863
# 98  Molecular Biology of the Cell Textbook  ISBN 9780393884864
# 99  Molecular Biology of the Cell Textbook  ISBN 9780393884865
#
# [100 rows x 3 columns]

# %%
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):

    # create a dictionary
    data = {}

    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)

        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:

            # Assuming a column named 'No' to
            # be the primary key
            key = rows['text']
            data[key] = rows

    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))

# Driver Code

# Decide the two file paths according to your
# computer system
csvFilePath = 'lrb_annotations.csv'
jsonFilePath = 'lrb_annotations.json'

# Call the make_json function
make_json(csvFilePath, jsonFilePath)
